# %% [markdown]
# <a href="https://colab.research.google.com/github/SruthiMarpu/fmml-projects-and-labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-17 05:38:13--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   119MB/s    in 0.6s
#
# 2024-04-17 05:38:15 (119 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22156  1506.02371v4  It is becoming increasingly important for mach...  stat
# 32678   1412.0233v3  We study the connection between the highly non...    cs
# 12370  1712.08449v1  We introduce a simple algorithm, True Asymptot...  stat
# 9367   1510.09130v1  In many statistical problems, a more coarse-gr...  stat
# 6149   1608.04471v2  We propose a general purpose variational infer...  stat
# ...             ...                                                ...   ...
# 5947    1305.5734v1  This paper proposes a generative model, the la...  stat
# 6565   1703.04823v1  Biological and cellular systems are often mode...  stat
# 2949   1801.08092v1  Machine learning models are susceptible to adv...    cs
# 22814  1707.05922v1  We propose a simple method that combines neura...  stat
# 394    1609.06666v2  This paper proposes a computationally efficien...    cs
#
#                                                    title  year  \
# 22156  Interpretable Selection and Visualization of F...  2015
# 32678           The Loss Surfaces of Multilayer Networks  2014
# 12370      True Asymptotic Natural Gradient Optimization  2017
# 9367   Latent Bayesian melding for integrating indivi...  2015
# 6149   Stein Variational Gradient Descent: A General ...  2016
# ...                                                  ...   ...
# 5947   Characterizing A Database of Sequential Behavi...  2013
# 6565   Classification in biological networks with hyp...  2017
# 2949   Generalizable Data-free Objective for Crafting...  2018
# 22814  Improving Output Uncertainty Estimation and Ge...  2017
# 394    Vote3Deep: Fast Object Detection in 3D Point C...  2016
#
#                                                 keywords
# 22156  [increasingly, important, predictions, interpr...
# 32678  [connection, connected, hamiltonian, spherical...
# 12370  [introduce, algorithm, asymptotic, optimizatio...
# 9367   [statistical, population, behaviour, appropria...
# 6149   [variational, inference, algorithm, counterpar...
# ...                                                  ...
# 5947   [generative, dirichlet, characterizing, sequen...
# 6565   [biological, represent, represent, relational,...
# 2949   [susceptible, adversarial, perturbations, demo...
# 22814  [processes, uncertainty, functions, advantages...
# 394    [computationally, efficient, detecting, convol...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22156    [increasingly, important, predictions, interpr...
# 32678    [connection, connected, hamiltonian, spherical...
# 12370    [introduce, algorithm, asymptotic, optimizatio...
# 9367     [statistical, population, behaviour, appropria...
# 6149     [variational, inference, algorithm, counterpar...
#                                ...
# 12045    [conditional, discrimination, discrimination, ...
# 19199    [probability, semantics, particularly, probabi...
# 7085     [classification, challenge, agreement, efficie...
# 4914     [considerable, algorithms, properties, algorit...
# 26916    [atmosphere, parameter, defogging, algorithms,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8702 words.
# Out of those 4589 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c2d723e8-78c9-4b3f-a74e-775e196d2e7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2d723e8-78c9-4b3f-a74e-775e196d2e7f")) {                    Plotly.newPlot(                        "c2d723e8-78c9-4b3f-a74e-775e196d2e7f",                        [{"x":["important","increasingly","according","practical","prediction","parsimonious","performing","predictive","benchmarks","interactions","classification","structured","relevance","predictions","interaction","interpretable","dimensions","selection","competitively","detection","interpretability","simultaneously","applications","selective","classifier","visualization","multilayer","conjecture","simulated","decoupled","exponentially","structure","uniformity","assumptions","recovered","overfitting","emphasizes","probability","independence","spherical","redundancy","dependencies","increases","connection","connected","difference","empirically","mathematical","complexity","simulations","hamiltonian","irrelevant","parametrization","recovering","annealing","converges","estimation","introduce","different","linearization","sometimes","algorithm","asymptotic","asymptotically","quadratic","particular","optimization","dimension","parameter","approximate","lightweight","stochastic","arbitrarily","regularization","framework","distributions","behaviour","individual","integrating","separation","appropriate","expressed","significantly","expectations","generalized","integrate","statistical","population","averaging","populations","modelling","statistics","logarithmic","posterior","disaggregation","motivated","conveniently","electricity","independent","particles","iteratively","derivation","divergence","inference","competitive","variational","functional","minimizes","empirical","derivative","counterpart","transforms","theoretical","discrepancy","kernelized","distribution","performed","transports","participants","interesting","dirichlet","multinomial","probabilistic","unsupervised","including","syntactic","concentration","categories","discussion","categorization","component","influencing","identification","utilization","documents","information","naturally","performance","effective","determined","polarities","adjectives","assessment","emanating","investigated","contribute","presented","associated","representation","themselves","sentiment","comparison","generated","experimental","available","application","following","knowledge","questions","comprehension","proportion","characteristics","extracted","especially","challenging","annotations","indicates","experiments","estimating","primarily","principled","sufficient","conditions","fundamental","numerical","constraints","expansion","tractable","correlations","arbitrary","identifiability","variables","implement","components","development","principal","extractor","extraction","equations","preliminary","amortization","intractable","amortized","optimized","interface","parameters","represent","programming","generative","unfortunately"],"y":[362,45,102,146,238,6,72,57,119,80,512,114,27,85,98,31,38,149,1,340,14,109,419,19,160,30,16,9,71,3,26,354,4,65,9,16,3,184,35,6,18,48,44,51,69,62,66,62,219,54,4,16,5,18,12,19,203,340,762,1,26,823,28,12,28,273,300,57,109,106,10,150,23,91,550,112,34,122,38,21,87,38,273,9,64,48,168,57,20,17,54,60,21,39,2,52,4,5,129,8,31,6,24,221,126,65,42,13,150,5,19,19,134,5,6,210,120,0,26,73,26,4,157,141,253,49,12,68,29,20,98,4,97,10,60,678,53,885,248,37,3,5,42,2,53,33,181,119,366,19,47,137,174,365,324,254,65,336,72,13,9,94,106,124,277,51,18,642,65,25,23,65,145,81,92,145,21,25,35,89,4,153,66,98,118,31,10,117,32,37,1,28,1,54,34,253,111,104,128,25],"type":"bar"},{"x":["important","increasingly","according","practical","prediction","parsimonio ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4589,), (4589, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7841666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Generalized</span> <span style=''>Value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Iteration</span> <span style=''>Networks</span> <span style=''>Life</span> <span style=''>Beyond</span> <span style=''>Lattices</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalized</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>network</span> <span style=''>(GVIN)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>an</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>planning</span> <span style=''>module</span> <span style=''>GVIN</span> <span style=''>emulates</span> <span style=''>the</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>by</span> <span style=''>using</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.6271186440677965);'>convolution</span> <span style=''>operator</span> <span style=''>which</span> <span style=''>enables</span> <span style=''>GVIN</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>and</span> <span style=''>plan</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.8823529411764706);'>irregular</span> <span style=''>spatial</span> <span style=''>graphs</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>three</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differentiable</span> <span style=''>kernels</span> <span style=''>as</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.6271186440677965);'>convolution</span> <span style='background-color:rgba(0, 255, 0, 0.32352941176470584);'>operators</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>based</span> <span style=''>kernel</span> <span style=''>achieves</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>We</span> <span style=''>further</span> <span style=''>propose</span> <span style=''>episodic</span> <span style=''>Q</span> <span style=''>learning</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3789954337899543);'>improvement</span> <span style=''>upon</span> <span style='background-color:rgba(0, 255, 0, 0.3135593220338982);'>traditional</span> <span style=''>n</span> <span style=''>step</span> <span style=''>Q</span> <span style=''>learning</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>stabilizes</span> <span style=''>training</span> <span style=''>for</span> <span style=''>networks</span> <span style=''>that</span> <span style=''>contain</span> <span style=''>a</span> <span style=''>planning</span> <span style=''>module</span> <span style=''>Lastly</span> <span style=''>we</span> <span style=''>evaluate</span> <span style=''>GVIN</span> <span style=''>on</span> <span style=''>planning</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>2D</span> <span style=''>mazes</span> <span style='background-color:rgba(0, 255, 0, 0.8823529411764706);'>irregular</span> <span style=''>graphs</span> <span style=''>and</span> <span style=''>real</span> <span style=''>world</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Determinantal</span> <span style=''>Point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Determinantal</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>(DPPs)</span> <span style=''>are</span> <span style=''>random</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>well</span> <span style=''>suited</span> <span style=''>for</span> <span style=''>modeling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>repulsion</span> <span style=''>In</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>focus</span> <span style=''>of</span> <span style=''>DPP</span> <span style=''>based</span> <span style=''>models</span> <span style=''>has</span> <span style=''>been</span> <span style=''>on</span> <span style=''>diverse</span> <span style=''>subset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>from</span> <span style=''>a</span> <span style=''>discrete</span> <span style=''>and</span> <span style=''>finite</span> <span style=''>base</span> <span style=''>set</span> <span style=''>This</span> <span style=''>discrete</span> <span style=''>setting</span> <span style=''>admits</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigendecomposition</span> <span style=''>of</span> <span style=''>the</span> <span style=''>defining</span> <span style=''>kernel</span> <span style=''>matrix</span> <span style=''>Recently</span> <span style=''>there</span> <span style=''>has</span> <span style=''>been</span> <span style=''>growing</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>using</span> <span style=''>DPPs</span> <span style=''>defined</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>spaces</span> <span style=''>While</span> <span style=''>the</span> <span style=''>discrete</span> <span style=''>DPP</span> <span style=''>sampler</span> <span style=''>extends</span> <span style=''>formally</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>case</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style=''>the</span> <span style=''>steps</span> <span style=''>required</span> <span style=''>are</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractable</span> <span style=''>in</span> <span style=''>general</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>DPP</span> <span style=''>sampling</span> <span style=''>schemes</span> <span style=''>that</span> <span style=''>apply</span> <span style=''>to</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>one</span> <span style=''>based</span> <span style=''>on</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <span style=''>with</span> <span style=''>Billions</span> <span style=''>of</span> <span style=''>Inducing</span> <span style=''>Inputs</span> <span style=''>via</span> <span style=''>Tensor</span> <span style=''>Train</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposition</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>(TT</span> <span style=''>GP)</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>(GP)</span> <span style=''>models</span> <span style=''>We</span> <span style=''>build</span> <span style=''>on</span> <span style=''>previous</span> <span style=''>scalable</span> <span style=''>GP</span> <span style=''>research</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.5057034220532319);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>based</span> <span style=''>on</span> <span style=''>inducing</span> <span style=''>inputs</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpolation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploiting</span> <span style=''>algebra</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>our</span> <span style=''>method</span> <span style=''>is</span> <span style=''>to</span> <span style=''>use</span> <span style=''>Tensor</span> <span style=''>Train</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5057034220532319);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>train</span> <span style=''>GPs</span> <span style=''>with</span> <span style=''>billions</span> <span style=''>of</span> <span style=''>inducing</span> <span style=''>inputs</span> <span style=''>and</span> <span style=''>achieve</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>results</span> <span style=''>on</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.5657894736842105);'>benchmarks</span> <span style=''>Further</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>allows</span> <span style=''>for</span> <span style=''>training</span> <span style=''>kernels</span> <span style=''>based</span> <span style=''>on</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>without</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3846153846153846);'>modifications</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>GP</span> <span style=''>model</span> <span style=''>A</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>learns</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multidimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>for</span> <span style=''>the</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Large</span> <span style=''>Scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experimental</span> <span style=''>Design</span> <span style=''>for</span> <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalized</span> <span style=''>Linear</span> <span style=''>Models</span> <br/><br/><span style=''>Many</span> <span style=''>problems</span> <span style=''>of</span> <span style=''>low</span> <span style=''>level</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>and</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>denoising</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deconvolution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tomographic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>or</span> <span style=''>super</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolution</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addressed</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>linear</span> <span style=''>model</span> <span style=''>(SLM)</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>higher</span> <span style=''>order</span> <span style=''>Bayesian</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>problems</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquisition</span> <span style=''>in</span> <span style=''>magnetic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resonance</span> <span style=''>scanners</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addressed</span> <span style=''>by</span> <span style=''>querying</span> <span style=''>the</span> <span style=''>SLM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unrelated</span> <span style=''>to</span> <span style=''>the</span> <span style=''>densitys</span> <span style=''>mode</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>with</span> <span style=''>which</span> <span style=''>SLM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posteriors</span> <span style=''>over</span> <span style=''>full</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolution</span> <span style=''>images</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximated</span> <span style=''>for</span> <span style=''>the</span> <span style=''>first</span> <span style=''>time</span> <span style=''>solving</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10393756651294786)
# 	information (0.24051081943951755)
# 	architecture (0.08194395175594182)
# 	challenging (0.09826179496275275)
# 	segmentation (0.06846399432422845)
# 	representation (0.12983327421071303)
# 	detection (0.12061014544164597)
# 	different (0.27030862007804185)
# 	convolutional (0.12983327421071303)
# 	recognition (0.13728272437034408)
#
# Some Statistics words are:
# 	variables (0.13629480060575466)
# 	stochastic (0.13679959616355375)
# 	algorithm (0.381120646138314)
# 	theoretical (0.15093387178192832)
# 	statistical (0.16456335184250379)
# 	estimation (0.17869762746087833)
# 	distribution (0.1867743563856638)
# 	dimensional (0.19081272084805653)
# 	inference (0.20595658758202928)
# 	regression (0.18980312973245836)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e6c263db-d897-4ab0-8267-abe050d5ba45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6c263db-d897-4ab0-8267-abe050d5ba45")) {                    Plotly.newPlot(                        "e6c263db-d897-4ab0-8267-abe050d5ba45",                        [{"x":["important","increasingly","according","practical","prediction","parsimonious","performing","predictive","benchmarks","interactions","classification","structured","relevance","predictions","interaction","interpretable","dimensions","selection","competitively","detection","interpretability","simultaneously","applications","selective","classifier","visualization","multilayer","conjecture","simulated","decoupled","exponentially","structure","uniformity","assumptions","recovered","overfitting","emphasizes","probability","independence","spherical","redundancy","dependencies","increases","connection","connected","difference","empirically","mathematical","complexity","simulations","hamiltonian","irrelevant","parametrization","recovering","annealing","converges","estimation","introduce","different","linearization","sometimes","algorithm","asymptotic","asymptotically","quadratic","particular","optimization","dimension","parameter","approximate","lightweight","stochastic","arbitrarily","regularization","framework","distributions","behaviour","individual","integrating","separation","appropriate","expressed","significantly","expectations","generalized","integrate","statistical","population","averaging","populations","modelling","statistics","logarithmic","posterior","disaggregation","motivated","conveniently","electricity","independent","particles","iteratively","derivation","divergence","inference","competitive","variational","functional","minimizes","empirical","derivative","counterpart","transforms","theoretical","discrepancy","kernelized","distribution","performed","transports","participants","interesting","dirichlet","multinomial","probabilistic","unsupervised","including","syntactic","concentration","categories","discussion","categorization","component","influencing","identification","utilization","documents","information","naturally","performance","effective","determined","polarities","adjectives","assessment","emanating","investigated","contribute","presented","associated","representation","themselves","sentiment","comparison","generated","experimental","available","application","following","knowledge","questions","comprehension","proportion","characteristics","extracted","especially","challenging","annotations","indicates","experiments","estimating","primarily","principled","sufficient","conditions","fundamental","numerical","constraints","expansion","tractable","correlations","arbitrary","identifiability","variables","implement","components","development","principal","extractor","extraction","equations","preliminary","amortization","intractable","amortized","optimized","interface","parameters","represent","programming","generative","unfortunately","languages","expensive","specified","computable","approximately","supporting","automatically","alleviate","parameterized","inferences","optimizing","symmetric","perplexity","marginalized","properties","importance","efficient","algebraic","collapsed","factorization","carefully","characterization","illustrate","approaches","environment","observation","evolution","determine","characterizing","reliability","uncertainty","improvement","supervision","providing","reception","substantial","extensive","cooperation","architecture","hierarchical","convolutional","incorporates","attention","decreases","propagating","leveraging","benchmark","demonstrate","efficiently","processes","description","regression","extrapolation","composing","expl ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	transports
# 	marginalized
# 	periodicity
# 	statistician
# 	nonparametrically
# 	tibshirani
# 	transmitting
# 	pseudolikelihood
# 	electrocardiogram
# 	emphdirectly
# 	exoplanet
# 	confounders
# 	infectious
# 	smoothers
# 	morgenstern
# 	rescaling
# 	submanifold
# 	increments
# 	overdetermined
# 	algebraically
# Some words which never appear in Statistics papers:
# 	emphasizes
# 	syntactic
# 	polarities
# 	adjectives
# 	emanating
# 	reception
# 	compartments
# 	diffeomorphic
# 	optimised
# 	occluding
# 	deblurring
# 	visuomotor
# 	abbreviations
# 	coreference
# 	abbreviation
# 	functionalities
# 	functionally
# 	imagination
# 	disparities
# 	translating

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0507337014552002e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7358333333333333
